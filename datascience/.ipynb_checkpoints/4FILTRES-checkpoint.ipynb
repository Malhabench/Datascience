# %%
import pandas as pd
df=pd.read_csv("data.csv")
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
 df["gender"] == "Female"
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 995     True
# 996     True
# 997    False
# 998    False
# 999    False
# Name: gender, Length: 1000, dtype: bool

# %%
df[df["gender"]=="Female"]
# Out:
#       id        date first_name   last_name                       email  \
# 1      2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org
# 3      4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 5      6  03/25/2021      Titos  Braybrooke        tbraybrooke5@umn.edu
# 6      7  03/14/2021        Ava     Kencott          akencott6@phoca.cz
# 12    13  03/05/2021     Janice    Morillas  jmorillasc@miibeian.gov.cn
# ..   ...         ...        ...         ...                         ...
# 985  986  03/29/2021     Yvonne  Longworthy       ylongworthyrd@163.com
# 988  989  03/07/2021       Yves      Botler  ybotlerrg@miitbeian.gov.cn
# 994  995  03/17/2021   Carolyne    Bruntjen   cbruntjenrm@reference.com
# 995  996  03/24/2021       Duff      Errigo        derrigorn@elpais.com
# 996  997  03/17/2021        Ame     Rastall       arastallro@toplist.cz
#
#      gender      ip_address        country price_paid   tax
# ...

# %%
df[df["gender"]=="Male"]
# Out:
#       id        date first_name   last_name                       email  \
# 0      1  03/28/2021    Marylin      Alders        malders0@shop-pro.jp
# 2      3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 4      5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# 7      8  03/08/2021       Codi     Feasley            cfeasley7@ed.gov
# 8      9  03/09/2021     Waylon    Heersema       wheersema8@tumblr.com
# ..   ...         ...        ...         ...                         ...
# 991  992  03/07/2021      Elihu       Crush       ecrushrj@berkeley.edu
# 992  993  03/04/2021    Maurene  Guilloneau      mguilloneaurk@about.me
# 993  994  03/22/2021      Ossie      Snelle            osnellerl@nhs.uk
# 997  998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 998  999  03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp
#
#     gender       ip_address        country price_paid   tax
# ...

# %%
df[df["gender"] !="Male"]
# Out:
#        id        date first_name     last_name                       email  \
# 1       2  03/19/2021      Hinda      Harridge          hharridge1@gnu.org
# 3       4  03/19/2021      Grata        Brantl            gbrantl3@umn.edu
# 5       6  03/25/2021      Titos    Braybrooke        tbraybrooke5@umn.edu
# 6       7  03/14/2021        Ava       Kencott          akencott6@phoca.cz
# 12     13  03/05/2021     Janice      Morillas  jmorillasc@miibeian.gov.cn
# ..    ...         ...        ...           ...                         ...
# 989   990  03/16/2021   Horatius  Van Arsdalen    hvanarsdalenrh@prlog.org
# 994   995  03/17/2021   Carolyne      Bruntjen   cbruntjenrm@reference.com
# 995   996  03/24/2021       Duff        Errigo        derrigorn@elpais.com
# 996   997  03/17/2021        Ame       Rastall       arastallro@toplist.cz
# 999  1000  03/23/2021   Rochelle      Pringuer       rpringuerrr@house.gov
#
#      gender      ip_address        country price_paid   tax
# ...

# %%
df[df["gender"] !="Male"] & df[df["gender"] !="Female"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File C:\Python311\Lib\site-packages\pandas\core\ops\array_ops.py:362, in na_logical_op(x, y, op)
#     353 try:
#     354     # For exposition, write:
#     355     #  yarr = isinstance(y, np.ndarray)
#    (...)
#     360     # Then Cases where this goes through without raising include:
#     361     #  (xint or xbool) and (yint or bool)
# --> 362     result = op(x, y)
#     363 except TypeError:
#
# TypeError: unsupported operand type(s) for &: 'float' and 'float'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df[df["gender"] !="Male"] & df[df["gender"] !="Female"]
#
# File C:\Python311\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
# ...

# %%
df[df["gender"]=="Male"]
# Out:
#       id        date first_name   last_name                       email  \
# 0      1  03/28/2021    Marylin      Alders        malders0@shop-pro.jp
# 2      3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 4      5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# 7      8  03/08/2021       Codi     Feasley            cfeasley7@ed.gov
# 8      9  03/09/2021     Waylon    Heersema       wheersema8@tumblr.com
# ..   ...         ...        ...         ...                         ...
# 991  992  03/07/2021      Elihu       Crush       ecrushrj@berkeley.edu
# 992  993  03/04/2021    Maurene  Guilloneau      mguilloneaurk@about.me
# 993  994  03/22/2021      Ossie      Snelle            osnellerl@nhs.uk
# 997  998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 998  999  03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp
#
#     gender       ip_address        country price_paid   tax
# ...

# %%
female= df["gender"]=="Female"
df[female]
# Out:
#       id        date first_name   last_name                       email  \
# 1      2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org
# 3      4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 5      6  03/25/2021      Titos  Braybrooke        tbraybrooke5@umn.edu
# 6      7  03/14/2021        Ava     Kencott          akencott6@phoca.cz
# 12    13  03/05/2021     Janice    Morillas  jmorillasc@miibeian.gov.cn
# ..   ...         ...        ...         ...                         ...
# 985  986  03/29/2021     Yvonne  Longworthy       ylongworthyrd@163.com
# 988  989  03/07/2021       Yves      Botler  ybotlerrg@miitbeian.gov.cn
# 994  995  03/17/2021   Carolyne    Bruntjen   cbruntjenrm@reference.com
# 995  996  03/24/2021       Duff      Errigo        derrigorn@elpais.com
# 996  997  03/17/2021        Ame     Rastall       arastallro@toplist.cz
#
#      gender      ip_address        country price_paid   tax
# ...

# %%
 country_filtre=df["country"].isin(("France","Canada"))
df[country_filtre]
# Out:
#        id        date first_name   last_name                      email  \
# 0       1  03/28/2021    Marylin      Alders       malders0@shop-pro.jp
# 1       2  03/19/2021      Hinda    Harridge         hharridge1@gnu.org
# 6       7  03/14/2021        Ava     Kencott         akencott6@phoca.cz
# 7       8  03/08/2021       Codi     Feasley           cfeasley7@ed.gov
# 8       9  03/09/2021     Waylon    Heersema      wheersema8@tumblr.com
# ..    ...         ...        ...         ...                        ...
# 992   993  03/04/2021    Maurene  Guilloneau     mguilloneaurk@about.me
# 993   994  03/22/2021      Ossie      Snelle           osnellerl@nhs.uk
# 994   995  03/17/2021   Carolyne    Bruntjen  cbruntjenrm@reference.com
# 995   996  03/24/2021       Duff      Errigo       derrigorn@elpais.com
# 999  1000  03/23/2021   Rochelle    Pringuer      rpringuerrr@house.gov
#
#      gender      ip_address country price_paid   tax
# ...

# %%
df["price_paid"]=float(df["price_paid"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df["price_paid"]=float(df["price_paid"])
#
# File C:\Python311\Lib\site-packages\pandas\core\series.py:248, in _coerce_method.<locals>.wrapper(self)
#     240     warnings.warn(
#     241         f"Calling {converter.__name__} on a single element Series is "
#     242         "deprecated and will raise a TypeError in the future. "
#    (...)
#     245         stacklevel=find_stack_level(),
#     246     )
#     247     return converter(self.iloc[0])
# --> 248 raise TypeError(f"cannot convert the series to {converter}")
#
# TypeError: cannot convert the series to <class 'float'>

# %%
df["price_paid"] = df["price_paid"].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df["price_paid"] = df["price_paid"].astype(float)
#
# File C:\Python311\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File C:\Python311\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
# ...

# %% [markdown]
# #Filtrer le prix ( chaune=> entier)

# %%
df_copy=df.copy()
df_copy.price_paid=df_copy.price_paid.apply(lambda x : x.replace("$",""))
df_copy.price_paid=df_copy.price_paid.astype(float)
df_copy[df_copy["price_paid"]<= 5]
# Out:
#       id        date first_name   last_name                        email  \
# 2      3  03/17/2021        Erl  Kilminster        ekilminster2@etsy.com
# 3      4  03/19/2021      Grata      Brantl             gbrantl3@umn.edu
# 7      8  03/08/2021       Codi     Feasley             cfeasley7@ed.gov
# 8      9  03/09/2021     Waylon    Heersema        wheersema8@tumblr.com
# 11    12  03/16/2021     Bailie       Wyman             bwymanb@lulu.com
# ..   ...         ...        ...         ...                          ...
# 984  985  03/17/2021    Koressa      Abbado  kabbadorc@printfriendly.com
# 986  987  03/05/2021      Dukey     Espinal   despinalre@accuweather.com
# 993  994  03/22/2021      Ossie      Snelle             osnellerl@nhs.uk
# 995  996  03/24/2021       Duff      Errigo         derrigorn@elpais.com
# 996  997  03/17/2021        Ame     Rastall        arastallro@toplist.cz
#
#      gender      ip_address        country  price_paid   tax
# ...

# %%
female=df[gender]="female"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 female=df[gender]="female"
#
# NameError: name 'df' is not defined

# %%
female=df[[gender]="female"]
# Out:
#   Cell In[2], line 1
#     female=df[[gender]="female"]
#                       ^
# SyntaxError: invalid syntax

# %%
female=df[[gender]=="female"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 female=df[[gender]=="female"]
#
# NameError: name 'df' is not defined

# %%
female=df[["gender"]="female"]
# Out:
#   Cell In[4], line 1
#     female=df[["gender"]="female"]
#                         ^
# SyntaxError: invalid syntax

# %%
female=df[["gender"]=="female"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 female=df[["gender"]=="female"]
#
# NameError: name 'df' is not defined

# %%
df["gender"]=="female"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df["gender"]=="female"
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
df=pd.read_csv("data.csv")
df["gender"]=="female"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: gender, Length: 1000, dtype: bool

# %%
df_fem=df[["gender"]=="female"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\Python311\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df_fem=df[["gender"]=="female"]
#
# ...

# %%
fem=df["gender"]=="Female"

# %%
df[fem]
# Out:
# Empty DataFrame
# Columns: [id, date, first_name, last_name, email, gender, ip_address, country, price_paid, tax]
# Index: []

# %%
fem=df["gender"]=="Female"
df[fem]
# Out:
#       id        date first_name   last_name                       email  \
# 1      2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org
# 3      4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 5      6  03/25/2021      Titos  Braybrooke        tbraybrooke5@umn.edu
# 6      7  03/14/2021        Ava     Kencott          akencott6@phoca.cz
# 12    13  03/05/2021     Janice    Morillas  jmorillasc@miibeian.gov.cn
# ..   ...         ...        ...         ...                         ...
# 985  986  03/29/2021     Yvonne  Longworthy       ylongworthyrd@163.com
# 988  989  03/07/2021       Yves      Botler  ybotlerrg@miitbeian.gov.cn
# 994  995  03/17/2021   Carolyne    Bruntjen   cbruntjenrm@reference.com
# 995  996  03/24/2021       Duff      Errigo        derrigorn@elpais.com
# 996  997  03/17/2021        Ame     Rastall       arastallro@toplist.cz
#
#      gender      ip_address        country price_paid   tax
# ...

# %%
df["gender"].isin(["Male","Female"])
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 995     True
# 996     True
# 997     True
# 998     True
# 999    False
# Name: gender, Length: 1000, dtype: bool

# %%
df["country"].isin(["Morocco","Canada"])
# Out:
# 0       True
# 1       True
# 2      False
# 3      False
# 4       True
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999     True
# Name: country, Length: 1000, dtype: bool

# %%
df["country"].isin(["France","Canada"])
# Out:
# 0       True
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 995     True
# 996    False
# 997    False
# 998    False
# 999     True
# Name: country, Length: 1000, dtype: bool

# %%
country_filter=df["country"].isin(["France","Canada"])
df[country_filter]
# Out:
#        id        date first_name   last_name                      email  \
# 0       1  03/28/2021    Marylin      Alders       malders0@shop-pro.jp
# 1       2  03/19/2021      Hinda    Harridge         hharridge1@gnu.org
# 6       7  03/14/2021        Ava     Kencott         akencott6@phoca.cz
# 7       8  03/08/2021       Codi     Feasley           cfeasley7@ed.gov
# 8       9  03/09/2021     Waylon    Heersema      wheersema8@tumblr.com
# ..    ...         ...        ...         ...                        ...
# 992   993  03/04/2021    Maurene  Guilloneau     mguilloneaurk@about.me
# 993   994  03/22/2021      Ossie      Snelle           osnellerl@nhs.uk
# 994   995  03/17/2021   Carolyne    Bruntjen  cbruntjenrm@reference.com
# 995   996  03/24/2021       Duff      Errigo       derrigorn@elpais.com
# 999  1000  03/23/2021   Rochelle    Pringuer      rpringuerrr@house.gov
#
#      gender      ip_address country price_paid   tax
# ...

# %%
 df_test=df.copy()
 df_test.price_paid=  df_test.price_paid.apply(lambda x: x.replace("$",""))
 df_test.price_paid= df_test.price_paid.astype(float) 
 df_test[ df_test["price_paid"]>=5.5]
# Out:
#        id        date first_name   last_name                       email  \
# 1       2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org
# 4       5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# 5       6  03/25/2021      Titos  Braybrooke        tbraybrooke5@umn.edu
# 6       7  03/14/2021        Ava     Kencott          akencott6@phoca.cz
# 9      10  03/23/2021  Guglielma      Gookes       ggookes9@amazon.co.uk
# ..    ...         ...        ...         ...                         ...
# 992   993  03/04/2021    Maurene  Guilloneau      mguilloneaurk@about.me
# 994   995  03/17/2021   Carolyne    Bruntjen   cbruntjenrm@reference.com
# 997   998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 998   999  03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp
# 999  1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov
#
#      gender       ip_address        country  price_paid   tax
# ...
