# %%
import pandas as pd
df=pd.read_csv("data.csv")

# %%
df.isnull()
# Out:
#         id   date  first_name  last_name  email  gender  ip_address  country  \
# 0    False  False       False      False  False   False       False    False
# 1    False  False       False      False  False   False       False    False
# 2    False  False       False      False  False   False       False    False
# 3    False  False       False      False  False   False       False    False
# 4    False  False       False      False  False   False       False    False
# ..     ...    ...         ...        ...    ...     ...         ...      ...
# 995  False  False       False      False  False   False       False    False
# 996  False  False       False      False  False   False       False     True
# 997  False  False       False      False  False   False       False    False
# 998  False  False       False      False  False   False       False    False
# 999  False  False       False      False  False    True       False    False
#
#      price_paid    tax
# ...

# %%
df.notnull()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.notnull()
#
# NameError: name 'df' is not defined

# %%
import pandas as pd 
df=pd.read_csv("data.csv")

# %%
df.isnull()
# Out:
#         id   date  first_name  last_name  email  gender  ip_address  country  \
# 0    False  False       False      False  False   False       False    False
# 1    False  False       False      False  False   False       False    False
# 2    False  False       False      False  False   False       False    False
# 3    False  False       False      False  False   False       False    False
# 4    False  False       False      False  False   False       False    False
# ..     ...    ...         ...        ...    ...     ...         ...      ...
# 995  False  False       False      False  False   False       False    False
# 996  False  False       False      False  False   False       False     True
# 997  False  False       False      False  False   False       False    False
# 998  False  False       False      False  False   False       False    False
# 999  False  False       False      False  False    True       False    False
#
#      price_paid    tax
# ...

# %%
des.isnotnull()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 des.isnotnull()
#
# NameError: name 'des' is not defined

# %%
import pandas as pd
df=pd.read_csv("data.csv")
df.notnull
# Out:
# <bound method DataFrame.notnull of        id        date first_name   last_name                       email  \
# 0       1  03/28/2021    Marylin      Alders        malders0@shop-pro.jp
# 1       2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org
# 2       3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 3       4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 4       5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# ..    ...         ...        ...         ...                         ...
# 995   996  03/24/2021       Duff      Errigo        derrigorn@elpais.com
# 996   997  03/17/2021        Ame     Rastall       arastallro@toplist.cz
# 997   998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 998   999  03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp
# 999  1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov
#
# ...

# %%
df[df["gender"].isnull()]
# Out:
#        id        date first_name     last_name                        email  \
# 13     14  03/24/2021       Cull        Vassie           cvassied@unblog.fr
# 17     18  03/20/2021       Esta       Boulden      ebouldenh@posterous.com
# 26     27  03/27/2021      Elyse      Glaysher    eglaysherq@mayoclinic.com
# 49     50  03/16/2021   Grantham        Kerins    gkerins1d@paginegialle.it
# 56     57  03/05/2021    Novelia      Najafian        nnajafian1k@cam.ac.uk
# ..    ...         ...        ...           ...                          ...
# 954   955  03/11/2021     Gordie      Rushbury            grushburyqi@51.la
# 977   978  03/14/2021     Bronny       Kemball    bkemballr5@thetimes.co.uk
# 984   985  03/17/2021    Koressa        Abbado  kabbadorc@printfriendly.com
# 989   990  03/16/2021   Horatius  Van Arsdalen     hvanarsdalenrh@prlog.org
# 999  1000  03/23/2021   Rochelle      Pringuer        rpringuerrr@house.gov
#
# ...

# %%
df[df["gender"].tail().isnull()]
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18756\3968987826.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df["gender"].tail().isnull()]
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df[df["gender"].tail().isnull()]
#
# File C:\Python311\Lib\site-packages\pandas\core\frame.py:4093, in DataFrame.__getitem__(self, key)
#    4091 # Do we have a (boolean) 1d indexer?
#    4092 if com.is_bool_indexer(key):
# -> 4093     return self._getitem_bool_array(key)
#    4095 # We are left with two options: a single key, and a collection of keys,
#    4096 # We interpret tuples as collections only for non-MultiIndex
#    4097 is_single_key = isinstance(key, tuple) or not is_list_like(key)
#
# File C:\Python311\Lib\site-packages\pandas\core\frame.py:4149, in DataFrame._getitem_bool_array(self, key)
# ...

# %%
df[df["gender"].isnull()]
# Out:
#        id        date first_name     last_name                        email  \
# 13     14  03/24/2021       Cull        Vassie           cvassied@unblog.fr
# 17     18  03/20/2021       Esta       Boulden      ebouldenh@posterous.com
# 26     27  03/27/2021      Elyse      Glaysher    eglaysherq@mayoclinic.com
# 49     50  03/16/2021   Grantham        Kerins    gkerins1d@paginegialle.it
# 56     57  03/05/2021    Novelia      Najafian        nnajafian1k@cam.ac.uk
# ..    ...         ...        ...           ...                          ...
# 954   955  03/11/2021     Gordie      Rushbury            grushburyqi@51.la
# 977   978  03/14/2021     Bronny       Kemball    bkemballr5@thetimes.co.uk
# 984   985  03/17/2021    Koressa        Abbado  kabbadorc@printfriendly.com
# 989   990  03/16/2021   Horatius  Van Arsdalen     hvanarsdalenrh@prlog.org
# 999  1000  03/23/2021   Rochelle      Pringuer        rpringuerrr@house.gov
#
# ...

# %%
import pandas as pd
df=pd.read_csv("data.csv")

# %%
df["tax"].notnull()
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 995    False
# 996     True
# 997     True
# 998    False
# 999     True
# Name: tax, Length: 1000, dtype: bool

# %%
df[df["tax"].notnull()]
# Out:
#        id        date first_name   last_name                       email  \
# 2       3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 3       4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 4       5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# 7       8  03/08/2021       Codi     Feasley            cfeasley7@ed.gov
# 8       9  03/09/2021     Waylon    Heersema       wheersema8@tumblr.com
# ..    ...         ...        ...         ...                         ...
# 991   992  03/07/2021      Elihu       Crush       ecrushrj@berkeley.edu
# 994   995  03/17/2021   Carolyne    Bruntjen   cbruntjenrm@reference.com
# 996   997  03/17/2021        Ame     Rastall       arastallro@toplist.cz
# 997   998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 999  1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov
#
#      gender       ip_address        country price_paid   tax
# ...

# %% [markdown]
# ### df[df["tax"].isnull()]

# %%
df[df["first_name"].isnull]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df[df["first_name"].isnull]
#
# File C:\Python311\Lib\site-packages\pandas\core\frame.py:4065, in DataFrame.__getitem__(self, key)
#    4063 check_dict_or_set_indexers(key)
#    4064 key = lib.item_from_zerodim(key)
# -> 4065 key = com.apply_if_callable(key, self)
#    4067 if is_hashable(key) and not is_iterator(key):
#    4068     # is_iterator to exclude generator e.g. test_getitem_listlike
#    4069     # shortcut if the key is in columns
#    4070     is_mi = isinstance(self.columns, MultiIndex)
#
# File C:\Python311\Lib\site-packages\pandas\core\common.py:384, in apply_if_callable(maybe_callable, obj, **kwargs)
#     373 """
#     374 Evaluate possibly callable input using obj and kwargs if it is callable,
#     375 otherwise return as it is.
#    (...)
#     381 **kwargs
#     382 """
# ...

# %%
df[df["gender"].isnull()]
# Out:
#        id        date first_name     last_name                        email  \
# 13     14  03/24/2021       Cull        Vassie           cvassied@unblog.fr
# 17     18  03/20/2021       Esta       Boulden      ebouldenh@posterous.com
# 26     27  03/27/2021      Elyse      Glaysher    eglaysherq@mayoclinic.com
# 49     50  03/16/2021   Grantham        Kerins    gkerins1d@paginegialle.it
# 56     57  03/05/2021    Novelia      Najafian        nnajafian1k@cam.ac.uk
# ..    ...         ...        ...           ...                          ...
# 954   955  03/11/2021     Gordie      Rushbury            grushburyqi@51.la
# 977   978  03/14/2021     Bronny       Kemball    bkemballr5@thetimes.co.uk
# 984   985  03/17/2021    Koressa        Abbado  kabbadorc@printfriendly.com
# 989   990  03/16/2021   Horatius  Van Arsdalen     hvanarsdalenrh@prlog.org
# 999  1000  03/23/2021   Rochelle      Pringuer        rpringuerrr@house.gov
#
# ...

# %%
df[df["gender"].notnull()]
# Out:
#       id        date first_name   last_name                       email  \
# 0      1  03/28/2021    Marylin      Alders        malders0@shop-pro.jp
# 1      2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org
# 2      3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 3      4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 4      5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# ..   ...         ...        ...         ...                         ...
# 994  995  03/17/2021   Carolyne    Bruntjen   cbruntjenrm@reference.com
# 995  996  03/24/2021       Duff      Errigo        derrigorn@elpais.com
# 996  997  03/17/2021        Ame     Rastall       arastallro@toplist.cz
# 997  998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 998  999  03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp
#
#      gender       ip_address        country price_paid   tax
# ...

# %%
df["tax"].fillna("malha")
# Out:
# 0      malha
# 1      malha
# 2       20.0
# 3       20.0
# 4       20.0
#        ...
# 995    malha
# 996     20.0
# 997     20.0
# 998    malha
# 999     20.0
# Name: tax, Length: 1000, dtype: object

# %%
df["tax"].fillna("isnull")
# Out:
# 0      isnull
# 1      isnull
# 2        20.0
# 3        20.0
# 4        20.0
#         ...
# 995    isnull
# 996      20.0
# 997      20.0
# 998    isnull
# 999      20.0
# Name: tax, Length: 1000, dtype: object

# %%
df["tax"].fillna(0)
# Out:
# 0       0.0
# 1       0.0
# 2      20.0
# 3      20.0
# 4      20.0
#        ...
# 995     0.0
# 996    20.0
# 997    20.0
# 998     0.0
# 999    20.0
# Name: tax, Length: 1000, dtype: float64

# %%
df.dropna()
# Out:
#       id        date first_name   last_name                       email  \
# 2      3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 3      4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 4      5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# 7      8  03/08/2021       Codi     Feasley            cfeasley7@ed.gov
# 8      9  03/09/2021     Waylon    Heersema       wheersema8@tumblr.com
# ..   ...         ...        ...         ...                         ...
# 988  989  03/07/2021       Yves      Botler  ybotlerrg@miitbeian.gov.cn
# 990  991  03/19/2021       Shep    Thorburn  sthorburnri@prnewswire.com
# 991  992  03/07/2021      Elihu       Crush       ecrushrj@berkeley.edu
# 994  995  03/17/2021   Carolyne    Bruntjen   cbruntjenrm@reference.com
# 997  998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
#
#      gender       ip_address        country price_paid   tax
# ...

# %%
df.dropna(subset=['tax'])
# Out:
#        id        date first_name   last_name                       email  \
# 2       3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 3       4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 4       5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# 7       8  03/08/2021       Codi     Feasley            cfeasley7@ed.gov
# 8       9  03/09/2021     Waylon    Heersema       wheersema8@tumblr.com
# ..    ...         ...        ...         ...                         ...
# 991   992  03/07/2021      Elihu       Crush       ecrushrj@berkeley.edu
# 994   995  03/17/2021   Carolyne    Bruntjen   cbruntjenrm@reference.com
# 996   997  03/17/2021        Ame     Rastall       arastallro@toplist.cz
# 997   998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 999  1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov
#
#      gender       ip_address        country price_paid   tax
# ...
