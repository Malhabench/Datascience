# %%
cd ..
# Out:
# C:\Users\Admin

# %%
# !zip -r TRAITEMENT.zip datascience
# Out:
#   adding: datascience/ (164 bytes security) (stored 0%)
#   adding: datascience/.ipynb_checkpoints/ (164 bytes security) (stored 0%)
#   adding: datascience/.ipynb_checkpoints/1readcsvfile-checkpoint.ipynb (164 bytes security) (deflated 21%)
#   adding: datascience/.ipynb_checkpoints/2analysedonn‚e-checkpoint.ipynb (164 bytes security) (deflated 89%)
#   adding: datascience/.ipynb_checkpoints/3selectdata-checkpoint.ipynb (164 bytes security) (deflated 80%)
#   adding: datascience/.ipynb_checkpoints/4FILTRES-checkpoint.ipynb (164 bytes security) (deflated 89%)
#   adding: datascience/.ipynb_checkpoints/5supprimercolonee-checkpoint.ipynb (164 bytes security) (deflated 90%)
#   adding: datascience/.ipynb_checkpoints/6valeursmanquantes-checkpoint.ipynb (164 bytes security) (deflated 21%)
#   adding: datascience/.ipynb_checkpoints/7addcolonnes-checkpoint.ipynb (164 bytes security) (deflated 90%)
# ...

# %%
# !zip -r datascience.zip datascience
# Out:
# updating: datascience/ (164 bytes security) (stored 0%)
# updating: datascience/.ipynb_checkpoints/ (164 bytes security) (stored 0%)
# updating: datascience/.ipynb_checkpoints/1readcsvfile-checkpoint.ipynb (164 bytes security) (deflated 21%)
# updating: datascience/.ipynb_checkpoints/2analysedonn‚e-checkpoint.ipynb (164 bytes security) (deflated 89%)
# updating: datascience/.ipynb_checkpoints/3selectdata-checkpoint.ipynb (164 bytes security) (deflated 80%)
# updating: datascience/.ipynb_checkpoints/4FILTRES-checkpoint.ipynb (164 bytes security) (deflated 89%)
# updating: datascience/.ipynb_checkpoints/5supprimercolonee-checkpoint.ipynb (164 bytes security) (deflated 90%)
# updating: datascience/.ipynb_checkpoints/6valeursmanquantes-checkpoint.ipynb (164 bytes security) (deflated 21%)
# updating: datascience/.ipynb_checkpoints/7addcolonnes-checkpoint.ipynb (164 bytes security) (deflated 90%)
# ...

# %%
import pandas as pd

# %%
df= pd.read_csv("data.csv")

# %%
df
# Out:
#        id        date first_name   last_name                       email  \
# 0       1  03/28/2021    Marylin      Alders        malders0@shop-pro.jp
# 1       2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org
# 2       3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 3       4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 4       5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# ..    ...         ...        ...         ...                         ...
# 995   996  03/24/2021       Duff      Errigo        derrigorn@elpais.com
# 996   997  03/17/2021        Ame     Rastall       arastallro@toplist.cz
# 997   998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# 998   999  03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp
# 999  1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov
#
#      gender       ip_address        country price_paid   tax
# ...

# %%
df.head()
# Out:
#    id        date first_name   last_name                  email  gender  \
# 0   1  03/28/2021    Marylin      Alders   malders0@shop-pro.jp    Male
# 1   2  03/19/2021      Hinda    Harridge     hharridge1@gnu.org  Female
# 2   3  03/17/2021        Erl  Kilminster  ekilminster2@etsy.com    Male
# 3   4  03/19/2021      Grata      Brantl       gbrantl3@umn.edu  Female
# 4   5  03/24/2021      Kanya     Beasant    kbeasant4@jigsy.com    Male
#
#         ip_address        country price_paid   tax
# 0    160.119.8.119         Canada      $5.36   NaN
# 1   210.51.172.132         Canada      $8.32   NaN
# 2    213.8.101.145  United States      $3.73  20.0
# 3    5.140.237.101  United States      $3.70  20.0
# 4  106.252.162.233        Morocco      $9.24  20.0

# %%
df.tail()
# Out:
#        id        date first_name last_name                       email  \
# 995   996  03/24/2021       Duff    Errigo        derrigorn@elpais.com
# 996   997  03/17/2021        Ame   Rastall       arastallro@toplist.cz
# 997   998  03/13/2021      Betty  Stickels  bstickelsrp@cloudflare.com
# 998   999  03/17/2021    Paquito     Tesoe      ptesoerq@rakuten.co.jp
# 999  1000  03/23/2021   Rochelle  Pringuer       rpringuerrr@house.gov
#
#      gender      ip_address        country price_paid   tax
# 995  Female  193.84.247.144         France      $3.63   NaN
# 996  Female  188.219.12.109            NaN      $4.59  20.0
# 997    Male    199.80.60.87  United States      $7.54  20.0
# 998    Male     0.183.63.11  United States      $5.81   NaN
# 999     NaN  170.193.249.83         Canada      $8.01  20.0

# %%
df.head(20)
# Out:
#     id        date first_name   last_name                       email  gender  \
# 0    1  03/28/2021    Marylin      Alders        malders0@shop-pro.jp    Male
# 1    2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org  Female
# 2    3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com    Male
# 3    4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu  Female
# 4    5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com    Male
# 5    6  03/25/2021      Titos  Braybrooke        tbraybrooke5@umn.edu  Female
# 6    7  03/14/2021        Ava     Kencott          akencott6@phoca.cz  Female
# 7    8  03/08/2021       Codi     Feasley            cfeasley7@ed.gov    Male
# 8    9  03/09/2021     Waylon    Heersema       wheersema8@tumblr.com    Male
# 9   10  03/23/2021  Guglielma      Gookes       ggookes9@amazon.co.uk    Male
# 10  11  03/11/2021       Lief   Woodcraft   lwoodcrafta@sitemeter.com    Male
# ...

# %%
df.tail(2)
# Out:
#        id        date first_name last_name                   email gender  \
# 998   999  03/17/2021    Paquito     Tesoe  ptesoerq@rakuten.co.jp   Male
# 999  1000  03/23/2021   Rochelle  Pringuer   rpringuerrr@house.gov    NaN
#
#          ip_address        country price_paid   tax
# 998     0.183.63.11  United States      $5.81   NaN
# 999  170.193.249.83         Canada      $8.01  20.0

# %%
df.tail(200)
# Out:
#        id        date first_name  last_name                       email  \
# 800   801  03/27/2021      Bucky  Grimsdell   bgrimsdellm8@japanpost.jp
# 801   802  03/21/2021      Rusty   Gisborne       rgisbornem9@state.gov
# 802   803  03/14/2021  Guillermo      Dando     gdandoma@washington.edu
# 803   804  03/07/2021     Elicia   Winspurr       ewinspurrmb@issuu.com
# 804   805  03/20/2021     Caesar   Spellesy       cspellesymc@lycos.com
# ..    ...         ...        ...        ...                         ...
# 995   996  03/24/2021       Duff     Errigo        derrigorn@elpais.com
# 996   997  03/17/2021        Ame    Rastall       arastallro@toplist.cz
# 997   998  03/13/2021      Betty   Stickels  bstickelsrp@cloudflare.com
# 998   999  03/17/2021    Paquito      Tesoe      ptesoerq@rakuten.co.jp
# 999  1000  03/23/2021   Rochelle   Pringuer       rpringuerrr@house.gov
#
#      gender      ip_address        country price_paid   tax
# ...

# %%
df.tail(30)
# Out:
#        id        date first_name     last_name                         email  \
# 970   971  03/27/2021    Abrahan         Osant          aosantqy@cbsnews.com
# 971   972  03/09/2021      Devan        Kamena             dkamenaqz@umn.edu
# 972   973  03/26/2021     Margie       Summons   msummonsr0@reverbnation.com
# 973   974  03/29/2021   Aridatha         Morse        amorser1@google.com.hk
# 974   975  03/07/2021   Nehemiah   Kitcherside  nkitchersider2@google.com.br
# 975   976  03/02/2021      Leroi         Latus      llatusr3@istockphoto.com
# 976   977  03/03/2021        Sax       Prichet            sprichetr4@psu.edu
# 977   978  03/14/2021     Bronny       Kemball     bkemballr5@thetimes.co.uk
# 978   979  03/18/2021  Bartolemo       Veelers         bveelersr6@smh.com.au
# 979   980  03/21/2021    Miquela        Geator             mgeatorr7@dot.gov
# 980   981  03/21/2021       Cari         Henze           chenzer8@toplist.cz
# ...

# %%
df.head(40)
# Out:
#     id        date  first_name      last_name                         email  \
# 0    1  03/28/2021     Marylin         Alders          malders0@shop-pro.jp
# 1    2  03/19/2021       Hinda       Harridge            hharridge1@gnu.org
# 2    3  03/17/2021         Erl     Kilminster         ekilminster2@etsy.com
# 3    4  03/19/2021       Grata         Brantl              gbrantl3@umn.edu
# 4    5  03/24/2021       Kanya        Beasant           kbeasant4@jigsy.com
# 5    6  03/25/2021       Titos     Braybrooke          tbraybrooke5@umn.edu
# 6    7  03/14/2021         Ava        Kencott            akencott6@phoca.cz
# 7    8  03/08/2021        Codi        Feasley              cfeasley7@ed.gov
# 8    9  03/09/2021      Waylon       Heersema         wheersema8@tumblr.com
# 9   10  03/23/2021   Guglielma         Gookes         ggookes9@amazon.co.uk
# 10  11  03/11/2021        Lief      Woodcraft     lwoodcrafta@sitemeter.com
# ...

# %%
df.head(100)
# Out:
#      id        date first_name   last_name                       email  \
# 0     1  03/28/2021    Marylin      Alders        malders0@shop-pro.jp
# 1     2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org
# 2     3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# 3     4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# 4     5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# ..  ...         ...        ...         ...                         ...
# 95   96  03/09/2021  Winnifred    Hallwood    whallwood2n@virginia.edu
# 96   97  03/20/2021    Devonne    Clowsley      dclowsley2o@ebay.co.uk
# 97   98  03/23/2021    Nikolai     Hallett  nhallett2p@marketwatch.com
# 98   99  03/06/2021    Gerardo      Antley           gantley2q@php.net
# 99  100  03/02/2021        Boy     Jimenez         bjimenez2r@ucla.edu
#
#     gender       ip_address        country price_paid   tax
# ...

# %% [markdown]
# #df.shape est un attribut non pas une methode ( we don't use () )

# %%
df.shape
# Out:
# (1000, 10)

# %%
df.columns
# Out:
# Index(['id', 'date', 'first_name', 'last_name', 'email', 'gender',
#        'ip_address', 'country', 'price_paid', 'tax'],
#       dtype='object')

# %%
df.columns.tolist()
# Out:
# ['id',
#  'date',
#  'first_name',
#  'last_name',
#  'email',
#  'gender',
#  'ip_address',
#  'country',
#  'price_paid',
#  'tax']

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df.set_index("email")
# Out:
#                               id        date first_name   last_name  gender  \
# email
# malders0@shop-pro.jp           1  03/28/2021    Marylin      Alders    Male
# hharridge1@gnu.org             2  03/19/2021      Hinda    Harridge  Female
# ekilminster2@etsy.com          3  03/17/2021        Erl  Kilminster    Male
# gbrantl3@umn.edu               4  03/19/2021      Grata      Brantl  Female
# kbeasant4@jigsy.com            5  03/24/2021      Kanya     Beasant    Male
# ...                          ...         ...        ...         ...     ...
# derrigorn@elpais.com         996  03/24/2021       Duff      Errigo  Female
# arastallro@toplist.cz        997  03/17/2021        Ame     Rastall  Female
# bstickelsrp@cloudflare.com   998  03/13/2021      Betty    Stickels    Male
# ptesoerq@rakuten.co.jp       999  03/17/2021    Paquito       Tesoe    Male
# rpringuerrr@house.gov       1000  03/23/2021   Rochelle    Pringuer     NaN
#
# ...

# %%
df.set_index("gender")
# Out:
#           id        date first_name   last_name                       email  \
# gender
# Male       1  03/28/2021    Marylin      Alders        malders0@shop-pro.jp
# Female     2  03/19/2021      Hinda    Harridge          hharridge1@gnu.org
# Male       3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com
# Female     4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu
# Male       5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com
# ...      ...         ...        ...         ...                         ...
# Female   996  03/24/2021       Duff      Errigo        derrigorn@elpais.com
# Female   997  03/17/2021        Ame     Rastall       arastallro@toplist.cz
# Male     998  03/13/2021      Betty    Stickels  bstickelsrp@cloudflare.com
# Male     999  03/17/2021    Paquito       Tesoe      ptesoerq@rakuten.co.jp
# NaN     1000  03/23/2021   Rochelle    Pringuer       rpringuerrr@house.gov
#
# ...

# %% [markdown]
# #modifier le df

# %%
df = df.set_index("email")

# %%
df
# Out:
#                               id        date first_name   last_name  gender  \
# email
# malders0@shop-pro.jp           1  03/28/2021    Marylin      Alders    Male
# hharridge1@gnu.org             2  03/19/2021      Hinda    Harridge  Female
# ekilminster2@etsy.com          3  03/17/2021        Erl  Kilminster    Male
# gbrantl3@umn.edu               4  03/19/2021      Grata      Brantl  Female
# kbeasant4@jigsy.com            5  03/24/2021      Kanya     Beasant    Male
# ...                          ...         ...        ...         ...     ...
# derrigorn@elpais.com         996  03/24/2021       Duff      Errigo  Female
# arastallro@toplist.cz        997  03/17/2021        Ame     Rastall  Female
# bstickelsrp@cloudflare.com   998  03/13/2021      Betty    Stickels    Male
# ptesoerq@rakuten.co.jp       999  03/17/2021    Paquito       Tesoe    Male
# rpringuerrr@house.gov       1000  03/23/2021   Rochelle    Pringuer     NaN
#
# ...

# %%
df.index
# Out:
# Index(['malders0@shop-pro.jp', 'hharridge1@gnu.org', 'ekilminster2@etsy.com',
#        'gbrantl3@umn.edu', 'kbeasant4@jigsy.com', 'tbraybrooke5@umn.edu',
#        'akencott6@phoca.cz', 'cfeasley7@ed.gov', 'wheersema8@tumblr.com',
#        'ggookes9@amazon.co.uk',
#        ...
#        'sthorburnri@prnewswire.com', 'ecrushrj@berkeley.edu',
#        'mguilloneaurk@about.me', 'osnellerl@nhs.uk',
#        'cbruntjenrm@reference.com', 'derrigorn@elpais.com',
#        'arastallro@toplist.cz', 'bstickelsrp@cloudflare.com',
#        'ptesoerq@rakuten.co.jp', 'rpringuerrr@house.gov'],
#       dtype='object', name='email', length=1000)

# %%
df.email
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.email
#
# NameError: name 'df' is not defined

# %%
df.email.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df.email.head()
#
# NameError: name 'df' is not defined

# %%
df=pd.read_csv("data.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df=pd.read_csv("data.csv")
#
# NameError: name 'pd' is not defined

# %%
df= pd.read_csv("data.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df= pd.read_csv("data.csv")
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd 
df=pd.read_csv("data.csv")

# %%
df.email
# Out:
# 0            malders0@shop-pro.jp
# 1              hharridge1@gnu.org
# 2           ekilminster2@etsy.com
# 3                gbrantl3@umn.edu
# 4             kbeasant4@jigsy.com
#                   ...
# 995          derrigorn@elpais.com
# 996         arastallro@toplist.cz
# 997    bstickelsrp@cloudflare.com
# 998        ptesoerq@rakuten.co.jp
# 999         rpringuerrr@house.gov
# Name: email, Length: 1000, dtype: object

# %%
df.gender
# Out:
# 0        Male
# 1      Female
# 2        Male
# 3      Female
# 4        Male
#         ...
# 995    Female
# 996    Female
# 997      Male
# 998      Male
# 999       NaN
# Name: gender, Length: 1000, dtype: object

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
 type(df.email)
# Out:
# pandas.core.series.Series

# %% [markdown]
# #dataFrame cest le tableau entier (lignes*columns)
# #Series cest une seule column

# %%
df[1:30]
# Out:
#     id        date  first_name   last_name                       email  \
# 1    2  03/19/2021       Hinda    Harridge          hharridge1@gnu.org
# 2    3  03/17/2021         Erl  Kilminster       ekilminster2@etsy.com
# 3    4  03/19/2021       Grata      Brantl            gbrantl3@umn.edu
# 4    5  03/24/2021       Kanya     Beasant         kbeasant4@jigsy.com
# 5    6  03/25/2021       Titos  Braybrooke        tbraybrooke5@umn.edu
# 6    7  03/14/2021         Ava     Kencott          akencott6@phoca.cz
# 7    8  03/08/2021        Codi     Feasley            cfeasley7@ed.gov
# 8    9  03/09/2021      Waylon    Heersema       wheersema8@tumblr.com
# 9   10  03/23/2021   Guglielma      Gookes       ggookes9@amazon.co.uk
# 10  11  03/11/2021        Lief   Woodcraft   lwoodcrafta@sitemeter.com
# 11  12  03/16/2021      Bailie       Wyman            bwymanb@lulu.com
# 12  13  03/05/2021      Janice    Morillas  jmorillasc@miibeian.gov.cn
# ...

# %%
 df.loc[1:3]
# Out:
#    id        date first_name   last_name                  email  gender  \
# 1   2  03/19/2021      Hinda    Harridge     hharridge1@gnu.org  Female
# 2   3  03/17/2021        Erl  Kilminster  ekilminster2@etsy.com    Male
# 3   4  03/19/2021      Grata      Brantl       gbrantl3@umn.edu  Female
#
#        ip_address        country price_paid   tax
# 1  210.51.172.132         Canada      $8.32   NaN
# 2   213.8.101.145  United States      $3.73  20.0
# 3   5.140.237.101  United States      $3.70  20.0

# %%
df_email= df.set_index("email")
df_email
# Out:
#                               id        date first_name   last_name  gender  \
# email
# malders0@shop-pro.jp           1  03/28/2021    Marylin      Alders    Male
# hharridge1@gnu.org             2  03/19/2021      Hinda    Harridge  Female
# ekilminster2@etsy.com          3  03/17/2021        Erl  Kilminster    Male
# gbrantl3@umn.edu               4  03/19/2021      Grata      Brantl  Female
# kbeasant4@jigsy.com            5  03/24/2021      Kanya     Beasant    Male
# ...                          ...         ...        ...         ...     ...
# derrigorn@elpais.com         996  03/24/2021       Duff      Errigo  Female
# arastallro@toplist.cz        997  03/17/2021        Ame     Rastall  Female
# bstickelsrp@cloudflare.com   998  03/13/2021      Betty    Stickels    Male
# ptesoerq@rakuten.co.jp       999  03/17/2021    Paquito       Tesoe    Male
# rpringuerrr@house.gov       1000  03/23/2021   Rochelle    Pringuer     NaN
#
# ...

# %%
df_mail.loc[malders0@shop-pro.jp]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df_mail.loc[ptesoerq@rakuten.co.jp]
#
# NameError: name 'df_mail' is not defined

# %%
df_mail.loc[ptesoerq@rakuten.co.jp : kbeasant4@jigsy.com]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df_mail.loc[ptesoerq@rakuten.co.jp : kbeasant4@jigsy.com]
#
# NameError: name 'df_mail' is not defined

# %%
df_email.loc['ptesoerq@rakuten.co.jp' ]
# Out:
# id                      999
# date             03/17/2021
# first_name          Paquito
# last_name             Tesoe
# gender                 Male
# ip_address      0.183.63.11
# country       United States
# price_paid            $5.81
# tax                     NaN
# Name: ptesoerq@rakuten.co.jp, dtype: object

# %%
df.loc[1]
# Out:
# id                             2
# date                  03/19/2021
# first_name                 Hinda
# last_name               Harridge
# email         hharridge1@gnu.org
# gender                    Female
# ip_address        210.51.172.132
# country                   Canada
# price_paid                 $8.32
# tax                          NaN
# Name: 1, dtype: object

# %%
df=df.set_index("email")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.set_index("email")
#
# NameError: name 'df' is not defined

# %%
df=df.set_index("email")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df=df.set_index("email")
#
# NameError: name 'df' is not defined

# %%
import pandas as pd 
df=pd.read_csv("data.csv")
df.set_index("email")
# Out:
#                               id        date first_name   last_name  gender  \
# email
# malders0@shop-pro.jp           1  03/28/2021    Marylin      Alders    Male
# hharridge1@gnu.org             2  03/19/2021      Hinda    Harridge  Female
# ekilminster2@etsy.com          3  03/17/2021        Erl  Kilminster    Male
# gbrantl3@umn.edu               4  03/19/2021      Grata      Brantl  Female
# kbeasant4@jigsy.com            5  03/24/2021      Kanya     Beasant    Male
# ...                          ...         ...        ...         ...     ...
# derrigorn@elpais.com         996  03/24/2021       Duff      Errigo  Female
# arastallro@toplist.cz        997  03/17/2021        Ame     Rastall  Female
# bstickelsrp@cloudflare.com   998  03/13/2021      Betty    Stickels    Male
# ptesoerq@rakuten.co.jp       999  03/17/2021    Paquito       Tesoe    Male
# rpringuerrr@house.gov       1000  03/23/2021   Rochelle    Pringuer     NaN
#
# ...
